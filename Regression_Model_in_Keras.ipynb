# %%
import pandas as pd
import numpy as np

# %%
concrete_data = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  ...  Fine Aggregate  Age  Strength
# 0   540.0                 0.0      0.0  ...           676.0   28     79.99
# 1   540.0                 0.0      0.0  ...           676.0   28     61.89
# 2   332.5               142.5      0.0  ...           594.0  270     40.27
# 3   332.5               142.5      0.0  ...           594.0  365     41.05
# 4   198.6               132.4      0.0  ...           825.5  360     44.30
#
# [5 rows x 9 columns]

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %%
concrete_data_columns = concrete_data.columns

predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %% [markdown]
# ## Import Keras

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
n_cols = predictors_norm.shape[1] # number of predictors

# %%
def regression_model():
  # create
  model = Sequential()
  model.add(Dense(10,activation='relu',input_shape=(n_cols,)))
  model.add(Dense(1))

  #compile model
  model.compile(optimizer='adam', loss='mean_squared_error')
  return model

# %% [markdown]
# # Part A

# %%
# fit the model
MSE = []

for i in range(50):
  model = regression_model()

  model.fit(predictors, target, validation_split=0.3, epochs=50, verbose=2)

  pre = model.predict(predictors)

  MSE.append(mean_squared_error(target, pre))
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Epoch 26/50
#  - 0s - loss: 127.7734 - val_loss: 126.2105
# Epoch 27/50
#  - 0s - loss: 123.6843 - val_loss: 124.6921
# Epoch 28/50
#  - 0s - loss: 120.7053 - val_loss: 119.1421
# Epoch 29/50
#  - 0s - loss: 118.9646 - val_loss: 119.1298
# Epoch 30/50
#  - 0s - loss: 114.7569 - val_loss: 121.2471
# Epoch 31/50
#  - 0s - loss: 109.9727 - val_loss: 121.2574
# Epoch 32/50
#  - 0s - loss: 108.8183 - val_loss: 123.0194
# Epoch 33/50
#  - 0s - loss: 106.3715 - val_loss: 117.1219
# Epoch 34/50
#  - 0s - loss: 105.0711 - val_loss: 116.6762
# Epoch 35/50
#  - 0s - loss: 104.0747 - val_loss: 115.9338
# Epoch 36/50
#  - 0s - loss: 101.0309 - val_loss: 117.0588
# Epoch 37/50
#  - 0s - loss: 99.3425 - val_loss: 114.1204
# Epoch 38/50
#  - 0s - loss: 98.0386 - val_loss: 120.2503
# Epoch 39/50
#  - 0s - loss: 97.9970 - val_loss: 112.5624
# Epoch 40/50
#  - 0s - loss: 96.6305 - val_loss: 107.3372
# Epoch 41/50
#  - 0s - loss: 95.2208 - val_loss: 106.6537
# Epoch 42/50
# ...

# %%
np.mean(MSE)
# Out:
# 330.47680080414705

# %% [markdown]
# #Part B

# %%
# fit the model
MSE_B = []

for i in range(50):
  model = regression_model()

  model.fit(predictors_norm, target, validation_split=0.3, epochs=50, verbose=2)

  pre = model.predict(predictors_norm)

  MSE_B.append(mean_squared_error(target, pre))
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Epoch 26/50
#  - 0s - loss: 969.7371 - val_loss: 776.4559
# Epoch 27/50
#  - 0s - loss: 929.6416 - val_loss: 753.5796
# Epoch 28/50
#  - 0s - loss: 890.3829 - val_loss: 730.1661
# Epoch 29/50
#  - 0s - loss: 850.9531 - val_loss: 707.6863
# Epoch 30/50
#  - 0s - loss: 813.1654 - val_loss: 684.1383
# Epoch 31/50
#  - 0s - loss: 775.2605 - val_loss: 661.4678
# Epoch 32/50
#  - 0s - loss: 739.0926 - val_loss: 639.5859
# Epoch 33/50
#  - 0s - loss: 703.0634 - val_loss: 617.9753
# Epoch 34/50
#  - 0s - loss: 669.3156 - val_loss: 596.3469
# Epoch 35/50
#  - 0s - loss: 636.4892 - val_loss: 575.4169
# Epoch 36/50
#  - 0s - loss: 605.7657 - val_loss: 555.2316
# Epoch 37/50
#  - 0s - loss: 576.0951 - val_loss: 535.8418
# Epoch 38/50
#  - 0s - loss: 548.0928 - val_loss: 517.3033
# Epoch 39/50
#  - 0s - loss: 522.3528 - val_loss: 498.6444
# Epoch 40/50
#  - 0s - loss: 498.2171 - val_loss: 480.7786
# Epoch 41/50
#  - 0s - loss: 475.2441 - val_loss: 463.7189
# ...

# %%
np.mean(MSE_B)
# Out:
# 376.52056286723086

# %% [markdown]
# #Part C

# %%
# fit the model
MSE_C = []

for i in range(50):
  model = regression_model()

  model.fit(predictors_norm, target, validation_split=0.3, epochs=100, verbose=2)

  pre = model.predict(predictors_norm)

  MSE_C.append(mean_squared_error(target, pre))
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#  - 0s - loss: 1434.5241 - val_loss: 1074.7390
# Epoch 14/100
#  - 0s - loss: 1404.8761 - val_loss: 1056.6106
# Epoch 15/100
#  - 0s - loss: 1373.9465 - val_loss: 1037.4488
# Epoch 16/100
#  - 0s - loss: 1340.6173 - val_loss: 1017.6722
# Epoch 17/100
#  - 0s - loss: 1306.9252 - val_loss: 996.4481
# Epoch 18/100
#  - 0s - loss: 1271.1967 - val_loss: 974.6836
# Epoch 19/100
#  - 0s - loss: 1234.5280 - val_loss: 952.2727
# Epoch 20/100
#  - 0s - loss: 1196.5981 - val_loss: 928.7004
# Epoch 21/100
#  - 0s - loss: 1157.7025 - val_loss: 905.0025
# Epoch 22/100
#  - 0s - loss: 1118.7775 - val_loss: 880.8155
# Epoch 23/100
#  - 0s - loss: 1079.1007 - val_loss: 856.0390
# Epoch 24/100
#  - 0s - loss: 1038.7143 - val_loss: 831.2404
# Epoch 25/100
#  - 0s - loss: 998.5501 - val_loss: 806.5674
# Epoch 26/100
#  - 0s - loss: 958.8943 - val_loss: 781.2026
# Epoch 27/100
#  - 0s - loss: 918.8696 - val_loss: 756.1821
# Epoch 28/100
# ...

# %%
np.mean(MSE_C)
# Out:
# 180.6268997641018

# %% [markdown]
# #Part D

# %%
def regression_model_2():
  # create
  model = Sequential()
  model.add(Dense(10,activation='relu',input_shape=(n_cols,)))
  model.add(Dense(10,activation='relu'))
  model.add(Dense(10,activation='relu'))
  model.add(Dense(1))

  #compile model
  model.compile(optimizer='adam', loss='mean_squared_error')
  return model

# %%
# fit the model
MSE_D = []

for i in range(50):
  model = regression_model_2()

  model.fit(predictors_norm, target, validation_split=0.3, epochs=100, verbose=2)

  pre = model.predict(predictors_norm)

  MSE_D.append(mean_squared_error(target, pre))
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#  - 0s - loss: 221.6256 - val_loss: 140.6820
# Epoch 14/100
#  - 0s - loss: 214.0496 - val_loss: 139.9265
# Epoch 15/100
#  - 0s - loss: 206.8036 - val_loss: 136.9977
# Epoch 16/100
#  - 0s - loss: 201.8426 - val_loss: 132.8331
# Epoch 17/100
#  - 0s - loss: 196.3487 - val_loss: 132.7311
# Epoch 18/100
#  - 0s - loss: 191.8917 - val_loss: 131.1806
# Epoch 19/100
#  - 0s - loss: 188.1379 - val_loss: 130.8276
# Epoch 20/100
#  - 0s - loss: 184.8369 - val_loss: 128.3222
# Epoch 21/100
#  - 0s - loss: 181.5050 - val_loss: 129.6193
# Epoch 22/100
#  - 0s - loss: 178.9866 - val_loss: 126.4309
# Epoch 23/100
#  - 0s - loss: 175.7654 - val_loss: 128.4948
# Epoch 24/100
#  - 0s - loss: 173.4244 - val_loss: 126.8064
# Epoch 25/100
#  - 0s - loss: 170.8366 - val_loss: 125.6856
# Epoch 26/100
#  - 0s - loss: 168.6809 - val_loss: 126.8277
# Epoch 27/100
#  - 0s - loss: 166.2803 - val_loss: 127.8692
# Epoch 28/100
#  - 0s - loss: 164.0971 - val_loss: 126.0905
# ...

# %%
np.mean(MSE_D)
# Out:
# 98.34795318291373
